# %% [markdown]
# # A small introduction to Pandas
#
# Pandas is a library that allows you to do data anlysis, manipulation and storing very easily in python. It is called using the following command: import pandas as pd

# %%
import pandas as pd

#read a file into pandas by using the read_csv function (there are other read function, that you can look up)

df = pd.read_csv('/home/dhruvy/Datasets/GTD/gtd.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-5e569deca852> in <module>()
#       3 #read a file into pandas by using the read_csv function (there are other read function, that you can look up)
#       4
# ----> 5 df = pd.read_csv('/home/dhruvy/Datasets/GTD/gtd.csv')
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 156767  201512310032   2015      12    31                  NaN         0
# 156768  201512310033   2015      12    31  2015-12-31 00:00:00         0
# 156769  201512310034   2015      12    31                  NaN         0
# 156770  201512310036   2015      12    31  2015-12-31 00:00:00         0
# 156771  201512310037   2015      12    31                  NaN         1
#
#        resolution  country  country_txt  region   ...     \
# 156767        NaN       34      Burundi      11   ...
# 156768        NaN       96      Ireland       8   ...
# 156769        NaN      160  Philippines       5   ...
# 156770        NaN      182      Somalia      11   ...
# 156771    1/16/16      113        Libya      10   ...
#
#                                                  addnotes  \
# 156767  Casualty numbers for this incident conflict ac...
# 156768                                                NaN
# ...

# %%
df.shape
# Out:
# (156772, 137)

# %%
df.columns
# Out:
# Index([u'eventid', u'iyear', u'imonth', u'iday', u'approxdate', u'extended',
#        u'resolution', u'country', u'country_txt', u'region',
#        ...
#        u'addnotes', u'scite1', u'scite2', u'scite3', u'dbsource', u'INT_LOG',
#        u'INT_IDEO', u'INT_MISC', u'INT_ANY', u'related'],
#       dtype='object', length=137)

# %%
df.dtypes
# Out:
# eventid                 int64
# iyear                   int64
# imonth                  int64
# iday                    int64
# approxdate             object
# extended                int64
# resolution             object
# country                 int64
# country_txt            object
# region                  int64
# region_txt             object
# provstate              object
# city                   object
# latitude              float64
# longitude             float64
# specificity             int64
# vicinity                int64
# location               object
# summary                object
# crit1                   int64
# crit2                   int64
# crit3                   int64
# doubtterr             float64
# alternative           float64
# alternative_txt        object
# multiple                int64
# success                 int64
# suicide                 int64
# attacktype1             int64
# attacktype1_txt        object
#                        ...
# ...

# %%
df2 = df[['nkill','nperps']]

df2.describe()
# Out:
#                nkill        nperps
# count  147827.000000  85640.000000
# mean        2.359237    -61.504437
# std        11.421270    243.824221
# min         0.000000    -99.000000
# 25%              NaN           NaN
# 50%              NaN           NaN
# 75%              NaN           NaN
# max      1500.000000  25000.000000

# %%
df[["nkill", "nperps", "country_txt"]].head()
# Out:
#    nkill  nperps         country_txt
# 0    1.0     NaN  Dominican Republic
# 1    0.0     7.0              Mexico
# 2    1.0     NaN         Philippines
# 3    NaN     NaN              Greece
# 4    NaN     NaN               Japan

# %%
df.sort_values(by='nkill', ascending = False)
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 133286  201406150063   2014       6    12                  NaN         1
# 73055   200109110005   2001       9    11                  NaN         0
# 73054   200109110004   2001       9    11                  NaN         0
# 55858   199404130008   1994       4    13                  NaN         0
# 132993  201406100042   2014       6    10                  NaN         0
# 76258   200403210001   2004       3    21                  NaN         0
# 136503  201408200027   2014       8    19                  NaN         1
# 136045  201408090071   2014       8     3                  NaN         1
# 6553    197808190004   1978       8    19                  NaN         0
# 90276   200901170021   2009       1    17                  NaN         0
# 31519   198707180001   1987       7    18                  NaN         0
# 62394   199605230007   1996       5    23                  NaN         0
# ...

# %%
df2.columns = ['killed','killers']
df2.head()
# Out:
#    killed  killers
# 0     1.0      NaN
# 1     0.0      7.0
# 2     1.0      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
df2.killed.std()
# Out:
# 11.421270347652616

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.ransomamt.hist()

# %%
df.ransomamt.std()
# Out:
# 31876939.23212349

# %%
df.index
# Out:
# RangeIndex(start=0, stop=156772, step=1)

# %%
china_data = df[df.country_txt == 'China']
china_data.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 37989  198904240015   1989       4    24        NaN         0        NaN
# 38623  198906260004   1989       6    26        NaN         0        NaN
# 40861  198912160006   1989      12    16        NaN         0        NaN
# 44726  199012070002   1990      12     7        NaN         0        NaN
# 45062  199101150001   1991       1    15        NaN         0        NaN
#
#        country country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 37989       44       China       4   ...         NaN    NaN    NaN     NaN
# 38623       44       China       4   ...         NaN    NaN    NaN     NaN
# 40861       44       China       4   ...         NaN    NaN    NaN     NaN
# 44726       44       China       4   ...         NaN    NaN    NaN     NaN
# 45062       44       China       4   ...         NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df2.killers = df2.killers.fillna(0)
df2.killers.mean()
# Out:
# /home/dhruvy/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# -33.5980914959304

# %%
big_attacks = df[df.nkill >= 200]
big_attacks.nkill.max()
# Out:
# 1500.0

# %%
medium = df[(df.nkill >= 0) & (df.nkill <= 50)]
medium.shape
# Out:
# (147211, 137)

# %%
df.nkill.sum()
# Out:
# 348758.9999981807

# %%
df['affected'] = df['ransomamt'] - df['ransompaid']
df.affected.mean()
# Out:
# 4441187.903081965

# %% [markdown]
# df.head()
# df.tail()
# df.shape
# df.columns
# df.dtypes
# df.describe()
#
# len(data)
# df[""]
# df.
# df[["", ""]]
# df[""].head()
#
# df.sort_values(by='country')
#
# df.columns = [] <-- Renaming columns
#
#
# df.<<Column Name>>.head()
#
# df.<Column Name>.std() <-- Will get you the standard deviation
#
# df.<<Column Name>>.hist() <-- Will draw a histogram for you of that column
#
# df.std() <-- Or of the entire dataset
#
# df['dt'] = pd.to_datetime(df['dt']) <-- Convert a column to datetime in pandas
#
# df.index
#
# df[df.country_txt == 'China'] <-- Only gives you country names for China
#
# df['nperps'].mean()
# pd.merge(left, right, on='key') #For merging datasets
#
# df[<<Column Name>>].dropna(how='any')
#
# df.<<Column Name>> = df.<<Column Name>>.fillna("")
#
# big_attacks = df[df.nperps >= 20]
#
# df[(df.nperps >= 20) & (df.nperps <= 100)] <-- Multiple conditions

# %%
# Creating New Columns

df['<<New Column Name>>'] = df['nperps'] - df['wounded']

df.nperps.sum() <-- aggregate operations
